# %%
import chess
import numpy as np
import polars as pl
from tqdm import tqdm, trange
from tinygrad import Tensor, nn, TinyJit

# %%
def fen_to_vec(fen: str) -> np.ndarray:
    vector = np.zeros(64 * 12, dtype=np.uint8)
    piece_types = [
        (chess.PAWN, chess.WHITE),
        (chess.KNIGHT, chess.WHITE),
        (chess.BISHOP, chess.WHITE),
        (chess.ROOK, chess.WHITE),
        (chess.QUEEN, chess.WHITE),
        (chess.KING, chess.WHITE),
        (chess.PAWN, chess.BLACK),
        (chess.KNIGHT, chess.BLACK),
        (chess.BISHOP, chess.BLACK),
        (chess.ROOK, chess.BLACK),
        (chess.QUEEN, chess.BLACK),
        (chess.KING, chess.BLACK),
    ]

    for i, (ptype, color) in enumerate(piece_types):
        for square in chess.Board(fen).pieces(ptype, color):
            vector[i * 64 + square] = 1

    return vector

def parse_eval(e: str) -> int:
    sign = -1 if e.startswith("-") else 1
    return int(e.strip("-").strip("+") ) * sign

# %%
print("Loading data")
df = pl.read_csv("./data.csv")
df = df.filter(pl.col("Evaluation").str.starts_with("#").not_())
df = df.sample(150_000)
train_df, test_df = df[:100_000], df[100_000:]
print("Loaded data")
x_train = [fen_to_vec(fen) for fen in tqdm(train_df["FEN"], desc="Processing training FENs")]
x_test = [fen_to_vec(fen) for fen in tqdm(test_df["FEN"], desc="Processing testing FENs")]
y_train = [parse_eval(e) for e in tqdm(train_df["Evaluation"], desc="Parsing training evals")]
y_test = [parse_eval(e) for e in tqdm(test_df["Evaluation"], desc="Parsing testing evals")]
# Out:
# Loading data
# Loaded data
# Processing training FENs:   0%|          | 0/100000 [00:00<?, ?it/s]
#
# Processing training FENs:   0%|          | 294/100000 [00:00<00:33, 2938.50it/s]
#
# Processing training FENs:   1%|          | 588/100000 [00:00<00:34, 2923.35it/s]
#
# Processing training FENs:   1%|          | 886/100000 [00:00<00:33, 2947.18it/s]
#
# Processing training FENs:   1%|          | 1181/100000 [00:00<00:33, 2931.58it/s]
#
# Processing training FENs:   1%|▏         | 1483/100000 [00:00<00:33, 2961.53it/s]
#
# Processing training FENs:   2%|▏         | 1780/100000 [00:00<00:33, 2942.51it/s]
#
# Processing training FENs:   2%|▏         | 2075/100000 [00:00<00:33, 2936.71it/s]
#
# Processing training FENs:   2%|▏         | 2369/100000 [00:00<00:33, 2918.89it/s]
#
# Processing training FENs:   3%|▎         | 2661/100000 [00:00<00:33, 2888.45it/s]
#
# Processing training FENs:   3%|▎         | 2950/100000 [00:01<00:33, 2887.53it/s]
#
# Processing training FENs:   3%|▎         | 3239/100000 [00:01<00:33, 2853.66it/s]
#
# Processing training FENs:   4%|▎         | 3528/100000 [00:01<00:33, 2863.67it/s]
#
# Processing training FENs:   4%|▍         | 3822/100000 [00:01<00:33, 2884.88it/s]
#
# Processing training FENs:   4%|▍         | 4111/100000 [00:01<00:33, 2841.02it/s]
#
# Processing training FENs:   4%|▍         | 4401/100000 [00:01<00:33, 2858.44it/s]
#
# Processing training FENs:   5%|▍         | 4687/100000 [00:01<00:33, 2849.11it/s]
#
# Processing training FENs:   5%|▍         | 4986/100000 [00:01<00:32, 2890.30it/s]
#
# Processing training FENs:   5%|▌         | 5277/100000 [00:01<00:32, 2895.03it/s]
#
# Processing training FENs:   6%|▌         | 5567/100000 [00:01<00:32, 2888.80it/s]
#
# Processing training FENs:   6%|▌         | 5856/100000 [00:02<00:32, 2883.69it/s]
#
# Processing training FENs:   6%|▌         | 6148/100000 [00:02<00:32, 2894.27it/s]
#
# Processing training FENs:   6%|▋         | 6443/100000 [00:02<00:32, 2910.23it/s]
#
# Processing training FENs:   7%|▋         | 6735/100000 [00:02<00:32, 2871.15it/s]
#
# Processing training FENs:   7%|▋         | 7025/100000 [00:02<00:32, 2878.03it/s]
#
# Processing training FENs:   7%|▋         | 7315/100000 [00:02<00:32, 2881.99it/s]
#
# Processing training FENs:   8%|▊         | 7608/100000 [00:02<00:31, 2895.16it/s]
#
# Processing training FENs:   8%|▊         | 7900/100000 [00:02<00:31, 2901.06it/s]
#
# Processing training FENs:   8%|▊         | 8191/100000 [00:02<00:31, 2879.71it/s]
#
# Processing training FENs:   8%|▊         | 8485/100000 [00:02<00:31, 2895.81it/s]
#
# Processing training FENs:   9%|▉         | 8776/100000 [00:03<00:31, 2897.58it/s]
#
# Processing training FENs:   9%|▉         | 9066/100000 [00:03<00:31, 2892.96it/s]
#
# Processing training FENs:   9%|▉         | 9356/100000 [00:03<00:31, 2891.21it/s]
#
# Processing training FENs:  10%|▉         | 9646/100000 [00:03<00:31, 2888.86it/s]
#
# Processing training FENs:  10%|▉         | 9937/100000 [00:03<00:31, 2891.51it/s]
#
# Processing training FENs:  10%|█         | 10227/100000 [00:03<00:31, 2887.69it/s]
#
# Processing training FENs:  11%|█         | 10521/100000 [00:03<00:30, 2900.63it/s]
#
# Processing training FENs:  11%|█         | 10815/100000 [00:03<00:30, 2911.03it/s]
#
# Processing training FENs:  11%|█         | 11107/100000 [00:03<00:30, 2885.43it/s]
#
# Processing training FENs:  11%|█▏        | 11405/100000 [00:03<00:30, 2912.87it/s]
#
# Processing training FENs:  12%|█▏        | 11701/100000 [00:04<00:30, 2925.65it/s]
#
# Processing training FENs:  12%|█▏        | 11994/100000 [00:04<00:30, 2892.40it/s]
#
# Processing training FENs:  12%|█▏        | 12284/100000 [00:04<00:30, 2874.75it/s]
#
# Processing training FENs:  13%|█▎        | 12583/100000 [00:04<00:30, 2907.12it/s]
#
# Processing training FENs:  13%|█▎        | 12876/100000 [00:04<00:29, 2912.90it/s]
#
# Processing training FENs:  13%|█▎        | 13168/100000 [00:04<00:30, 2879.03it/s]
#
# Processing training FENs:  13%|█▎        | 13457/100000 [00:04<00:30, 2872.10it/s]
#
# Processing training FENs:  14%|█▎        | 13749/100000 [00:04<00:29, 2885.78it/s]
#
# Processing training FENs:  14%|█▍        | 14044/100000 [00:04<00:29, 2903.73it/s]
#
# Processing training FENs:  14%|█▍        | 14335/100000 [00:04<00:29, 2881.96it/s]
#
# Processing training FENs:  15%|█▍        | 14628/100000 [00:05<00:29, 2894.58it/s]
#
# Processing training FENs:  15%|█▍        | 14919/100000 [00:05<00:29, 2898.58it/s]
#
# Processing training FENs:  15%|█▌        | 15209/100000 [00:05<00:29, 2880.15it/s]
#
# Processing training FENs:  16%|█▌        | 15503/100000 [00:05<00:29, 2896.69it/s]
#
# Processing training FENs:  16%|█▌        | 15802/100000 [00:05<00:28, 2923.21it/s]
#
# Processing training FENs:  16%|█▌        | 16095/100000 [00:05<00:29, 2887.92it/s]
#
# Processing training FENs:  16%|█▋        | 16390/100000 [00:05<00:28, 2905.64it/s]
#
# Processing training FENs:  17%|█▋        | 16687/100000 [00:05<00:28, 2924.05it/s]
#
# Processing training FENs:  17%|█▋        | 16980/100000 [00:05<00:28, 2900.25it/s]
#
# Processing training FENs:  17%|█▋        | 17272/100000 [00:05<00:28, 2904.92it/s]
#
# Processing training FENs:  18%|█▊        | 17568/100000 [00:06<00:28, 2918.28it/s]
#
# Processing training FENs:  18%|█▊        | 17860/100000 [00:06<00:28, 2914.33it/s]
#
# Processing training FENs:  18%|█▊        | 18152/100000 [00:06<00:28, 2912.13it/s]
#
# Processing training FENs:  18%|█▊        | 18444/100000 [00:06<00:28, 2909.62it/s]
#
# Processing training FENs:  19%|█▊        | 18735/100000 [00:06<00:28, 2898.41it/s]
#
# Processing training FENs:  19%|█▉        | 19033/100000 [00:06<00:27, 2921.41it/s]
#
# Processing training FENs:  19%|█▉        | 19332/100000 [00:06<00:27, 2938.27it/s]
#
# Processing training FENs:  20%|█▉        | 19626/100000 [00:06<00:27, 2928.12it/s]
#
# Processing training FENs:  20%|█▉        | 19927/100000 [00:06<00:27, 2950.78it/s]
#
# Processing training FENs:  20%|██        | 20226/100000 [00:06<00:26, 2961.38it/s]
#
# Processing training FENs:  21%|██        | 20523/100000 [00:07<00:26, 2945.69it/s]
#
# Processing training FENs:  21%|██        | 20823/100000 [00:07<00:26, 2960.90it/s]
#
# Processing training FENs:  21%|██        | 21125/100000 [00:07<00:26, 2978.04it/s]
#
# Processing training FENs:  21%|██▏       | 21423/100000 [00:07<00:26, 2946.47it/s]
#
# Processing training FENs:  22%|██▏       | 21718/100000 [00:07<00:26, 2928.24it/s]
#
# Processing training FENs:  22%|██▏       | 22011/100000 [00:07<00:26, 2926.00it/s]
#
# Processing training FENs:  22%|██▏       | 22307/100000 [00:07<00:26, 2934.74it/s]
#
# Processing training FENs:  23%|██▎       | 22601/100000 [00:07<00:26, 2934.79it/s]
#
# Processing training FENs:  23%|██▎       | 22895/100000 [00:07<00:26, 2917.47it/s]
#
# Processing training FENs:  23%|██▎       | 23189/100000 [00:07<00:26, 2923.28it/s]
#
# Processing training FENs:  23%|██▎       | 23487/100000 [00:08<00:26, 2939.76it/s]
#
# Processing training FENs:  24%|██▍       | 23787/100000 [00:08<00:25, 2957.33it/s]
#
# Processing training FENs:  24%|██▍       | 24083/100000 [00:08<00:25, 2956.15it/s]
#
# Processing training FENs:  24%|██▍       | 24379/100000 [00:08<00:25, 2943.86it/s]
#
# Processing training FENs:  25%|██▍       | 24681/100000 [00:08<00:25, 2963.63it/s]
#
# Processing training FENs:  25%|██▍       | 24978/100000 [00:08<00:25, 2947.13it/s]
#
# Processing training FENs:  25%|██▌       | 25273/100000 [00:08<00:25, 2930.48it/s]
#
# Processing training FENs:  76%|███████▋  | 76305/100000 [00:26<00:08, 2955.76it/s]
#
# Processing training FENs:  77%|███████▋  | 76601/100000 [00:26<00:07, 2953.44it/s]
#
# Processing training FENs:  77%|███████▋  | 76897/100000 [00:26<00:07, 2948.48it/s]
#
# Processing training FENs:  77%|███████▋  | 77204/100000 [00:26<00:07, 2983.32it/s]
#
# Processing training FENs:  78%|███████▊  | 77507/100000 [00:26<00:07, 2996.88it/s]
#
# Processing training FENs:  78%|███████▊  | 77811/100000 [00:26<00:07, 3009.76it/s]
#
# Processing training FENs:  78%|███████▊  | 78115/100000 [00:26<00:07, 3014.70it/s]
#
# Processing training FENs:  78%|███████▊  | 78417/100000 [00:26<00:07, 2995.79it/s]
#
# Processing training FENs:  79%|███████▊  | 78718/100000 [00:26<00:07, 2997.71it/s]
#
# Processing training FENs:  79%|███████▉  | 79018/100000 [00:26<00:07, 2994.96it/s]
#
# Processing training FENs:  79%|███████▉  | 79318/100000 [00:27<00:06, 2991.10it/s]
#
# Processing training FENs:  80%|███████▉  | 79618/100000 [00:27<00:06, 2988.17it/s]
#
# Processing training FENs:  80%|███████▉  | 79922/100000 [00:27<00:06, 3001.99it/s]
#
# Processing training FENs:  80%|████████  | 80223/100000 [00:27<00:06, 2982.44it/s]
#
# Processing training FENs:  81%|████████  | 80522/100000 [00:27<00:06, 2958.32it/s]
#
# Processing training FENs:  81%|████████  | 80823/100000 [00:27<00:06, 2971.52it/s]
#
# Processing training FENs:  81%|████████  | 81121/100000 [00:27<00:06, 2962.45it/s]
#
# Processing training FENs:  81%|████████▏ | 81418/100000 [00:27<00:06, 2957.38it/s]
#
# Processing training FENs:  82%|████████▏ | 81720/100000 [00:27<00:06, 2973.88it/s]
#
# Processing training FENs:  82%|████████▏ | 82018/100000 [00:27<00:06, 2975.09it/s]
#
# Processing training FENs:  82%|████████▏ | 82316/100000 [00:28<00:05, 2974.42it/s]
#
# Processing training FENs:  83%|████████▎ | 82614/100000 [00:28<00:05, 2973.24it/s]
#
# Processing training FENs:  83%|████████▎ | 82912/100000 [00:28<00:05, 2947.64it/s]
#
# Processing training FENs:  83%|████████▎ | 83207/100000 [00:28<00:05, 2944.94it/s]
#
# Processing training FENs:  84%|████████▎ | 83511/100000 [00:28<00:05, 2970.51it/s]
#
# Processing training FENs:  84%|████████▍ | 83809/100000 [00:28<00:05, 2965.14it/s]
#
# Processing training FENs:  84%|████████▍ | 84106/100000 [00:28<00:05, 2963.23it/s]
#
# Processing training FENs:  84%|████████▍ | 84403/100000 [00:28<00:05, 2955.62it/s]
#
# Processing training FENs:  85%|████████▍ | 84705/100000 [00:28<00:05, 2972.02it/s]
#
# Processing training FENs:  85%|████████▌ | 85005/100000 [00:28<00:05, 2979.96it/s]
#
# Processing training FENs:  85%|████████▌ | 85304/100000 [00:29<00:04, 2980.90it/s]
#
# Processing training FENs:  86%|████████▌ | 85603/100000 [00:29<00:04, 2975.72it/s]
#
# Processing training FENs:  86%|████████▌ | 85901/100000 [00:29<00:04, 2964.98it/s]
#
# Processing training FENs:  86%|████████▌ | 86200/100000 [00:29<00:04, 2969.48it/s]
#
# Processing training FENs:  86%|████████▋ | 86497/100000 [00:29<00:04, 2891.50it/s]
#
# Processing training FENs:  87%|████████▋ | 86792/100000 [00:29<00:04, 2905.64it/s]
#
# Processing training FENs:  87%|████████▋ | 87096/100000 [00:29<00:04, 2942.65it/s]
#
# Processing training FENs:  87%|████████▋ | 87402/100000 [00:29<00:04, 2976.97it/s]
#
# Processing training FENs:  88%|████████▊ | 87701/100000 [00:29<00:04, 2978.46it/s]
#
# Processing training FENs:  88%|████████▊ | 88000/100000 [00:29<00:04, 2978.16it/s]
#
# Processing training FENs:  88%|████████▊ | 88301/100000 [00:30<00:03, 2985.70it/s]
#
# Processing training FENs:  89%|████████▊ | 88602/100000 [00:30<00:03, 2990.08it/s]
#
# Processing training FENs:  89%|████████▉ | 88902/100000 [00:30<00:03, 2989.01it/s]
#
# Processing training FENs:  89%|████████▉ | 89204/100000 [00:30<00:03, 2995.28it/s]
#
# Processing training FENs:  90%|████████▉ | 89504/100000 [00:30<00:03, 2966.47it/s]
#
# Processing training FENs:  90%|████████▉ | 89801/100000 [00:30<00:03, 2934.56it/s]
#
# Processing training FENs:  90%|█████████ | 90095/100000 [00:30<00:03, 2930.20it/s]
#
# Processing training FENs:  90%|█████████ | 90389/100000 [00:30<00:03, 2922.07it/s]
#
# Processing training FENs:  91%|█████████ | 90694/100000 [00:30<00:03, 2959.11it/s]
#
# Processing training FENs:  91%|█████████ | 90995/100000 [00:31<00:03, 2973.84it/s]
#
# Processing training FENs:  91%|█████████▏| 91293/100000 [00:31<00:02, 2975.34it/s]
#
# Processing training FENs:  92%|█████████▏| 91591/100000 [00:31<00:02, 2970.48it/s]
#
# Processing training FENs:  92%|█████████▏| 91889/100000 [00:31<00:02, 2924.43it/s]
#
# Processing training FENs:  92%|█████████▏| 92182/100000 [00:31<00:02, 2789.66it/s]
#
# Processing training FENs:  92%|█████████▏| 92464/100000 [00:31<00:02, 2797.50it/s]
#
# Processing training FENs:  93%|█████████▎| 92745/100000 [00:31<00:02, 2763.07it/s]
#
# Processing training FENs:  93%|█████████▎| 93030/100000 [00:31<00:02, 2787.07it/s]
#
# Processing training FENs:  93%|█████████▎| 93326/100000 [00:31<00:02, 2834.79it/s]
#
# Processing training FENs:  94%|█████████▎| 93627/100000 [00:31<00:02, 2883.62it/s]
#
# Processing training FENs:  94%|█████████▍| 93926/100000 [00:32<00:02, 2912.06it/s]
#
# Processing training FENs:  94%|█████████▍| 94228/100000 [00:32<00:01, 2943.24it/s]
#
# Processing training FENs:  95%|█████████▍| 94526/100000 [00:32<00:01, 2954.00it/s]
#
# Processing training FENs:  95%|█████████▍| 94830/100000 [00:32<00:01, 2978.48it/s]
#
# Processing training FENs:  95%|█████████▌| 95128/100000 [00:32<00:01, 2958.06it/s]
#
# Processing training FENs:  95%|█████████▌| 95424/100000 [00:32<00:01, 2950.14it/s]
#
# Processing training FENs:  96%|█████████▌| 95723/100000 [00:32<00:01, 2961.24it/s]
#
# Processing training FENs:  96%|█████████▌| 96020/100000 [00:32<00:01, 2943.93it/s]
#
# Processing training FENs:  96%|█████████▋| 96323/100000 [00:32<00:01, 2967.10it/s]
#
# Processing training FENs:  97%|█████████▋| 96620/100000 [00:32<00:01, 2966.32it/s]
#
# Processing training FENs:  97%|█████████▋| 96917/100000 [00:33<00:01, 2944.06it/s]
#
# Processing training FENs:  97%|█████████▋| 97212/100000 [00:33<00:00, 2933.58it/s]
#
# Processing training FENs:  98%|█████████▊| 97506/100000 [00:33<00:00, 2929.68it/s]
#
# Processing training FENs:  98%|█████████▊| 97800/100000 [00:33<00:00, 2932.28it/s]
#
# Processing training FENs:  98%|█████████▊| 98094/100000 [00:33<00:00, 2928.22it/s]
#
# Processing training FENs:  98%|█████████▊| 98394/100000 [00:33<00:00, 2948.53it/s]
#
# Processing training FENs:  99%|█████████▊| 98690/100000 [00:33<00:00, 2950.89it/s]
#
# Processing training FENs:  99%|█████████▉| 98993/100000 [00:33<00:00, 2973.36it/s]
#
# Processing training FENs:  99%|█████████▉| 99291/100000 [00:33<00:00, 2964.88it/s]
#
# Processing training FENs: 100%|█████████▉| 99588/100000 [00:33<00:00, 2964.15it/s]
#
# Processing training FENs: 100%|██████████| 100000/100000 [00:34<00:00, 2933.51it/s][A
#
#
# Processing testing FENs:   0%|          | 0/50000 [00:00<?, ?it/s]
#
# Processing testing FENs:   1%|          | 298/50000 [00:00<00:16, 2978.31it/s]
#
# Processing testing FENs:   1%|          | 602/50000 [00:00<00:16, 3012.43it/s]
#
# Processing testing FENs:   2%|▏         | 904/50000 [00:00<00:16, 2949.38it/s]
#
# Processing testing FENs:   2%|▏         | 1200/50000 [00:00<00:16, 2952.95it/s]
#
# Processing testing FENs:   3%|▎         | 1497/50000 [00:00<00:16, 2958.71it/s]
#
# Processing testing FENs:   4%|▎         | 1800/50000 [00:00<00:16, 2980.61it/s]
#
# Processing testing FENs:   4%|▍         | 2099/50000 [00:00<00:16, 2971.77it/s]
#
# Processing testing FENs:   5%|▍         | 2401/50000 [00:00<00:15, 2985.69it/s]
#
# Processing testing FENs:   5%|▌         | 2700/50000 [00:00<00:15, 2967.44it/s]
#
# Processing testing FENs:   6%|▌         | 2997/50000 [00:01<00:15, 2939.17it/s]
#
# Processing testing FENs:   7%|▋         | 3291/50000 [00:01<00:15, 2935.55it/s]
#
# Processing testing FENs:   7%|▋         | 3585/50000 [00:01<00:15, 2933.22it/s]
#
# Processing testing FENs:   8%|▊         | 3881/50000 [00:01<00:15, 2939.23it/s]
#
# Processing testing FENs:   8%|▊         | 4175/50000 [00:01<00:15, 2918.95it/s]
#
# Processing testing FENs:   9%|▉         | 4469/50000 [00:01<00:15, 2921.76it/s]
#
# Processing testing FENs:  10%|▉         | 4776/50000 [00:01<00:15, 2964.12it/s]
#
# Processing testing FENs:  10%|█         | 5073/50000 [00:01<00:15, 2929.85it/s]
#
# Processing testing FENs:  11%|█         | 5367/50000 [00:01<00:15, 2913.09it/s]
#
# Processing testing FENs:  11%|█▏        | 5664/50000 [00:01<00:15, 2929.67it/s]
#
# Processing testing FENs:  12%|█▏        | 5958/50000 [00:02<00:15, 2916.01it/s]
#
# Processing testing FENs:  13%|█▎        | 6271/50000 [00:02<00:14, 2976.20it/s]
#
# Processing testing FENs:  13%|█▎        | 6571/50000 [00:02<00:14, 2982.97it/s]
#
# Processing testing FENs:  14%|█▎        | 6870/50000 [00:02<00:14, 2984.75it/s]
#
# Processing testing FENs:  14%|█▍        | 7169/50000 [00:02<00:14, 2981.75it/s]
#
# Processing testing FENs:  15%|█▍        | 7468/50000 [00:02<00:14, 2968.21it/s]
#
# Processing testing FENs:  16%|█▌        | 7765/50000 [00:02<00:14, 2939.41it/s]
#
# Processing testing FENs:  16%|█▌        | 8066/50000 [00:02<00:14, 2958.33it/s]
#
# Processing testing FENs:  17%|█▋        | 8362/50000 [00:02<00:14, 2955.58it/s]
#
# Processing testing FENs:  17%|█▋        | 8662/50000 [00:02<00:13, 2966.64it/s]
#
# Processing testing FENs:  18%|█▊        | 8959/50000 [00:03<00:13, 2950.37it/s]
#
# Processing testing FENs:  19%|█▊        | 9255/50000 [00:03<00:13, 2940.75it/s]
#
# Processing testing FENs:  19%|█▉        | 9550/50000 [00:03<00:13, 2931.77it/s]
#
# Processing testing FENs:  20%|█▉        | 9852/50000 [00:03<00:13, 2957.20it/s]
#
# Processing testing FENs:  20%|██        | 10148/50000 [00:03<00:13, 2949.74it/s]
#
# Processing testing FENs:  21%|██        | 10443/50000 [00:03<00:13, 2929.16it/s]
#
# Processing testing FENs:  21%|██▏       | 10743/50000 [00:03<00:13, 2950.00it/s]
#
# Processing testing FENs:  22%|██▏       | 11039/50000 [00:03<00:13, 2938.08it/s]
#
# Processing testing FENs:  23%|██▎       | 11340/50000 [00:03<00:13, 2957.95it/s]
#
# Processing testing FENs:  23%|██▎       | 11636/50000 [00:03<00:12, 2954.64it/s]
#
# Processing testing FENs:  24%|██▍       | 11940/50000 [00:04<00:12, 2979.92it/s]
#
# Processing testing FENs:  24%|██▍       | 12239/50000 [00:04<00:12, 2948.13it/s]
#
# Processing testing FENs:  25%|██▌       | 12539/50000 [00:04<00:12, 2960.85it/s]
#
# Processing testing FENs:  26%|██▌       | 12836/50000 [00:04<00:12, 2933.61it/s]
#
# Processing testing FENs:  26%|██▋       | 13133/50000 [00:04<00:12, 2941.80it/s]
#
# Processing testing FENs:  27%|██▋       | 13428/50000 [00:04<00:12, 2917.02it/s]
#
# Processing testing FENs:  27%|██▋       | 13720/50000 [00:04<00:12, 2913.71it/s]
#
# Processing testing FENs:  28%|██▊       | 14012/50000 [00:04<00:12, 2906.70it/s]
#
# Processing testing FENs:  29%|██▊       | 14310/50000 [00:04<00:12, 2927.81it/s]
#
# Processing testing FENs:  29%|██▉       | 14614/50000 [00:04<00:11, 2958.81it/s]
#
# Processing testing FENs:  30%|██▉       | 14910/50000 [00:05<00:11, 2948.88it/s]
#
# Processing testing FENs:  30%|███       | 15207/50000 [00:05<00:11, 2954.02it/s]
#
# Processing testing FENs:  31%|███       | 15503/50000 [00:05<00:11, 2931.47it/s]
#
# Processing testing FENs:  32%|███▏      | 15802/50000 [00:05<00:11, 2947.18it/s]
#
# Processing testing FENs:  32%|███▏      | 16106/50000 [00:05<00:11, 2971.94it/s]
#
# Processing testing FENs:  33%|███▎      | 16407/50000 [00:05<00:11, 2982.90it/s]
#
# Processing testing FENs:  33%|███▎      | 16706/50000 [00:05<00:11, 2983.63it/s]
#
# Processing testing FENs:  34%|███▍      | 17005/50000 [00:05<00:11, 2966.11it/s]
#
# Processing testing FENs:  35%|███▍      | 17303/50000 [00:05<00:11, 2967.77it/s]
#
# Processing testing FENs:  35%|███▌      | 17600/50000 [00:05<00:10, 2958.58it/s]
#
# Processing testing FENs:  36%|███▌      | 17899/50000 [00:06<00:10, 2965.87it/s]
#
# Processing testing FENs:  36%|███▋      | 18196/50000 [00:06<00:10, 2959.25it/s]
#
# Processing testing FENs:  37%|███▋      | 18496/50000 [00:06<00:10, 2969.68it/s]
#
# Processing testing FENs:  38%|███▊      | 18794/50000 [00:06<00:10, 2970.38it/s]
#
# Processing testing FENs:  38%|███▊      | 19094/50000 [00:06<00:10, 2975.07it/s]
#
# Processing testing FENs:  39%|███▉      | 19395/50000 [00:06<00:10, 2985.36it/s]
#
# Processing testing FENs:  39%|███▉      | 19700/50000 [00:06<00:10, 3002.35it/s]
#
# Processing testing FENs:  40%|████      | 20001/50000 [00:06<00:10, 2982.54it/s]
#
# Processing testing FENs:  41%|████      | 20300/50000 [00:06<00:10, 2960.11it/s]
#
# Processing testing FENs:  41%|████      | 20598/50000 [00:06<00:09, 2963.73it/s]
#
# Processing testing FENs:  42%|████▏     | 20895/50000 [00:07<00:09, 2963.91it/s]
#
# Processing testing FENs:  42%|████▏     | 21197/50000 [00:07<00:09, 2978.44it/s]
#
# Processing testing FENs:  43%|████▎     | 21495/50000 [00:07<00:09, 2968.16it/s]
#
# Processing testing FENs:  44%|████▎     | 21799/50000 [00:07<00:09, 2988.01it/s]
#
# Processing testing FENs:  44%|████▍     | 22098/50000 [00:07<00:09, 2984.25it/s]
#
# Processing testing FENs:  45%|████▍     | 22397/50000 [00:07<00:09, 2977.71it/s]
#
# Processing testing FENs:  45%|████▌     | 22699/50000 [00:07<00:09, 2988.13it/s]
#
# Processing testing FENs:  46%|████▌     | 23000/50000 [00:07<00:09, 2993.65it/s]
#
# Processing testing FENs:  47%|████▋     | 23300/50000 [00:07<00:08, 2983.85it/s]
#
# Processing testing FENs:  47%|████▋     | 23599/50000 [00:07<00:08, 2968.33it/s]
#
# Processing testing FENs:  48%|████▊     | 23900/50000 [00:08<00:08, 2980.22it/s]
#
# Processing testing FENs:  48%|████▊     | 24205/50000 [00:08<00:08, 2999.39it/s]
#
# Processing testing FENs:  49%|████▉     | 24505/50000 [00:08<00:08, 2969.10it/s]
#
# Processing testing FENs:  50%|████▉     | 24802/50000 [00:08<00:08, 2954.13it/s]
#
# Processing testing FENs:  50%|█████     | 25098/50000 [00:08<00:08, 2943.01it/s]
#
# Processing testing FENs:  51%|█████     | 25394/50000 [00:08<00:08, 2946.43it/s]
#
# Processing testing FENs:  51%|█████▏    | 25699/50000 [00:08<00:08, 2975.42it/s]
#
# Processing testing FENs:  52%|█████▏    | 26000/50000 [00:08<00:08, 2984.23it/s]
#
# Processing testing FENs:  53%|█████▎    | 26299/50000 [00:08<00:07, 2967.80it/s]
#
# Processing testing FENs:  53%|█████▎    | 26597/50000 [00:08<00:07, 2970.93it/s]
#
# Processing testing FENs:  54%|█████▍    | 26899/50000 [00:09<00:07, 2982.85it/s]
#
# Processing testing FENs:  54%|█████▍    | 27202/50000 [00:09<00:07, 2994.45it/s]
#
# Processing testing FENs:  55%|█████▌    | 27502/50000 [00:09<00:07, 2995.81it/s]
#
# Processing testing FENs:  56%|█████▌    | 27802/50000 [00:09<00:07, 2983.87it/s]
#
# Processing testing FENs:  56%|█████▌    | 28101/50000 [00:09<00:07, 2936.12it/s]
#
# Processing testing FENs:  57%|█████▋    | 28395/50000 [00:09<00:07, 2927.95it/s]
#
# Processing testing FENs:  57%|█████▋    | 28693/50000 [00:09<00:07, 2941.06it/s]
#
# Processing testing FENs:  58%|█████▊    | 28995/50000 [00:09<00:07, 2962.68it/s]
#
# Processing testing FENs:  59%|█████▊    | 29292/50000 [00:09<00:07, 2944.23it/s]
#
# Processing testing FENs:  59%|█████▉    | 29587/50000 [00:10<00:06, 2926.24it/s]
#
# Processing testing FENs:  60%|█████▉    | 29887/50000 [00:10<00:06, 2946.77it/s]
#
# Processing testing FENs:  60%|██████    | 30183/50000 [00:10<00:06, 2949.53it/s]
#
# Processing testing FENs:  61%|██████    | 30484/50000 [00:10<00:06, 2966.05it/s]
#
# Processing testing FENs:  62%|██████▏   | 30786/50000 [00:10<00:06, 2981.39it/s]
#
# Processing testing FENs:  62%|██████▏   | 31085/50000 [00:10<00:06, 2976.77it/s]
#
# Processing testing FENs:  63%|██████▎   | 31389/50000 [00:10<00:06, 2993.75it/s]
#
# Processing testing FENs:  63%|██████▎   | 31697/50000 [00:10<00:06, 3016.97it/s]
#
# Processing testing FENs:  64%|██████▍   | 31999/50000 [00:10<00:05, 3013.29it/s]
#
# Processing testing FENs:  65%|██████▍   | 32301/50000 [00:10<00:05, 2994.42it/s]
#
# Processing testing FENs:  65%|██████▌   | 32601/50000 [00:11<00:05, 2978.40it/s]
#
# Processing testing FENs:  66%|██████▌   | 32899/50000 [00:11<00:05, 2962.67it/s]
#
# Processing testing FENs:  66%|██████▋   | 33200/50000 [00:11<00:05, 2975.31it/s]
#
# Processing testing FENs:  67%|██████▋   | 33498/50000 [00:11<00:05, 2965.11it/s]
#
# Processing testing FENs:  68%|██████▊   | 33795/50000 [00:11<00:05, 2960.17it/s]
#
# Processing testing FENs:  68%|██████▊   | 34096/50000 [00:11<00:05, 2973.16it/s]
#
# Processing testing FENs:  69%|██████▉   | 34396/50000 [00:11<00:05, 2979.47it/s]
#
# Processing testing FENs:  69%|██████▉   | 34704/50000 [00:11<00:05, 3006.26it/s]
#
# Processing testing FENs:  70%|███████   | 35009/50000 [00:11<00:04, 3016.85it/s]
#
# Processing testing FENs:  71%|███████   | 35311/50000 [00:11<00:04, 3015.45it/s]
#
# Processing testing FENs:  71%|███████   | 35613/50000 [00:12<00:05, 2827.57it/s]
#
# Processing testing FENs:  72%|███████▏  | 35899/50000 [00:12<00:05, 2499.82it/s]
#
# Processing testing FENs:  72%|███████▏  | 36192/50000 [00:12<00:05, 2613.04it/s]
#
# Processing testing FENs:  73%|███████▎  | 36481/50000 [00:12<00:05, 2685.93it/s]
#
# Processing testing FENs:  74%|███████▎  | 36781/50000 [00:12<00:04, 2771.69it/s]
#
# Processing testing FENs:  74%|███████▍  | 37080/50000 [00:12<00:04, 2833.18it/s]
#
# Processing testing FENs:  75%|███████▍  | 37383/50000 [00:12<00:04, 2890.30it/s]
#
# Processing testing FENs:  75%|███████▌  | 37675/50000 [00:12<00:04, 2824.62it/s]
#
# Processing testing FENs:  76%|███████▌  | 37969/50000 [00:12<00:04, 2855.89it/s]
#
# Processing testing FENs:  77%|███████▋  | 38268/50000 [00:12<00:04, 2893.54it/s]
#
# Processing testing FENs:  77%|███████▋  | 38572/50000 [00:13<00:03, 2935.96it/s]
#
# Processing testing FENs:  78%|███████▊  | 38871/50000 [00:13<00:03, 2951.78it/s]
#
# Processing testing FENs:  78%|███████▊  | 39167/50000 [00:13<00:03, 2944.00it/s]
#
# Processing testing FENs:  79%|███████▉  | 39462/50000 [00:13<00:03, 2936.12it/s]
#
# Processing testing FENs:  80%|███████▉  | 39756/50000 [00:13<00:03, 2935.89it/s]
#
# Processing testing FENs:  80%|████████  | 40055/50000 [00:13<00:03, 2948.23it/s]
#
# Processing testing FENs:  81%|████████  | 40350/50000 [00:13<00:03, 2945.05it/s]
#
# Processing testing FENs:  81%|████████▏ | 40652/50000 [00:13<00:03, 2965.40it/s]
#
# Processing testing FENs:  82%|████████▏ | 40959/50000 [00:13<00:03, 2994.82it/s]
#
# Processing testing FENs:  83%|████████▎ | 41266/50000 [00:13<00:02, 3016.55it/s]
#
# Processing testing FENs:  83%|████████▎ | 41572/50000 [00:14<00:02, 3028.00it/s]
#
# Processing testing FENs:  84%|████████▍ | 41875/50000 [00:14<00:02, 2985.22it/s]
#
# Processing testing FENs:  84%|████████▍ | 42174/50000 [00:14<00:02, 2977.16it/s]
#
# Processing testing FENs:  85%|████████▍ | 42479/50000 [00:14<00:02, 2998.47it/s]
#
# Processing testing FENs:  86%|████████▌ | 42779/50000 [00:14<00:02, 2983.19it/s]
#
# Processing testing FENs:  86%|████████▌ | 43081/50000 [00:14<00:02, 2990.53it/s]
#
# Processing testing FENs:  87%|████████▋ | 43381/50000 [00:14<00:02, 2979.03it/s]
#
# Processing testing FENs:  87%|████████▋ | 43685/50000 [00:14<00:02, 2995.34it/s]
#
# Processing testing FENs:  88%|████████▊ | 43989/50000 [00:14<00:01, 3007.94it/s]
#
# Processing testing FENs:  89%|████████▊ | 44290/50000 [00:15<00:01, 2973.95it/s]
#
# Processing testing FENs:  89%|████████▉ | 44588/50000 [00:15<00:01, 2964.93it/s]
#
# Processing testing FENs:  90%|████████▉ | 44885/50000 [00:15<00:01, 2958.18it/s]
#
# Processing testing FENs:  90%|█████████ | 45184/50000 [00:15<00:01, 2966.05it/s]
#
# Processing testing FENs:  91%|█████████ | 45481/50000 [00:15<00:01, 2946.06it/s]
#
# Processing testing FENs:  92%|█████████▏| 45779/50000 [00:15<00:01, 2956.08it/s]
#
# Processing testing FENs:  92%|█████████▏| 46092/50000 [00:15<00:01, 3005.97it/s]
#
# Processing testing FENs:  93%|█████████▎| 46393/50000 [00:15<00:01, 2988.23it/s]
#
# Processing testing FENs:  93%|█████████▎| 46692/50000 [00:15<00:01, 2971.36it/s]
#
# Processing testing FENs:  94%|█████████▍| 46990/50000 [00:15<00:01, 2967.26it/s]
#
# Processing testing FENs:  95%|█████████▍| 47287/50000 [00:16<00:00, 2961.87it/s]
#
# Processing testing FENs:  95%|█████████▌| 47591/50000 [00:16<00:00, 2983.77it/s]
#
# Processing testing FENs:  96%|█████████▌| 47890/50000 [00:16<00:00, 2962.17it/s]
#
# Processing testing FENs:  96%|█████████▋| 48192/50000 [00:16<00:00, 2977.01it/s]
#
# Processing testing FENs:  97%|█████████▋| 48490/50000 [00:16<00:00, 2959.90it/s]
#
# Processing testing FENs:  98%|█████████▊| 48787/50000 [00:16<00:00, 2946.47it/s]
#
# Processing testing FENs:  98%|█████████▊| 49082/50000 [00:16<00:00, 2931.64it/s]
#
# Processing testing FENs:  99%|█████████▉| 49378/50000 [00:16<00:00, 2937.24it/s]
#
# Processing testing FENs:  99%|█████████▉| 49677/50000 [00:16<00:00, 2951.57it/s]
#
# Processing testing FENs: 100%|██████████| 50000/50000 [00:16<00:00, 2951.58it/s]
#
#
# Parsing training evals: 100%|██████████| 100000/100000 [00:00<00:00, 2859531.76it/s]
#
#
# Parsing testing evals: 100%|██████████| 50000/50000 [00:00<00:00, 2888360.63it/s]

# %%
x_train = Tensor(x_train)
y_train = Tensor(y_train)
x_test = Tensor(x_test)
y_test = Tensor(y_test)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 x_train = Tensor(x_train)
#       2 y_train = Tensor(y_train)
#       3 x_test = Tensor(x_test)
#
# File ~/Documents/Coding/gce/nnue/train/.venv/lib/python3.12/site-packages/tinygrad/tensor.py:167, in Tensor.__init__(self, data, device, dtype, requires_grad)
#     164   data = UOp.new_buffer(f"DISK:{data.resolve()}", data.stat().st_size // dtype.itemsize, dtype)
#     166 # by this point, it has to be a UOp
# --> 167 if not isinstance(data, UOp): raise RuntimeError(f"can't create Tensor from {data!r} with type {type(data)}")
#     169 # data might be on a different device
#     170 if isinstance(device, str): self.lazydata:UOp = data if data.device == device else data.copy_to_device(device)
#
# RuntimeError: can't create Tensor from <Tensor <UOp METAL (100000, 768) float (<Ops.COPY: 7>, None)> on METAL with grad None> with type <class 'tinygrad.tensor.Tensor'>

# %%
class Model:
    def __init__(self):
        self.l1 = nn.Linear(64*12, 512)
        self.l2 = nn.Linear(512, 256)
        self.l3 = nn.Linear(256, 64)
        self.l4 = nn.Linear(64, 1)

    def __call__(self, x: Tensor) -> Tensor:
        x = self.l1(x).relu()
        x = self.l2(x).relu()
        x = self.l3(x).relu()
        x = self.l4(x)

        return x

# %%
batch_size = 128
model = Model()
optim = nn.optim.Adam(nn.state.get_parameters(model))

@TinyJit
def step():
  Tensor.training = True
  samples = Tensor.randint(batch_size, high=x_train.shape[0])
  x, y = x_train[samples], y_train[samples]
  optim.zero_grad()
  loss = model(x).sub(y).pow(2).mean().backward()
  optim.step()
  return loss

# %%
for n in trange(7000):
    loss = step()
    if n % 100 == 0:
        Tensor.training = False
        acc = (model(x_test).argmax(axis=1) == y_test).mean().item()
        tqdm.write(f"step {n:4d}, loss {loss.item():.2f}, acc {acc * 100.:.2f}%")
# Out:
#   0%|          | 1/7000 [00:01<3:39:34,  1.88s/it]
# step    0, loss 987333.31, acc 10.20%
#   1%|          | 81/7000 [00:19<27:56,  4.13it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 2
#       1 for n in trange(7000):
# ----> 2     loss = step()
#       3     if n % 100 == 0:
#       4         Tensor.training = False
#
# File ~/Documents/Coding/gce/nnue/train/.venv/lib/python3.12/site-packages/tinygrad/engine/jit.py:328, in TinyJit.__call__(self, *args, **kwargs)
#     325   assert self.captured.expected_names == names, f"args mismatch in JIT: {self.captured.expected_names=} != {names}"
#     326   assert self.captured.expected_st_vars_dtype_device == st_vars_dtype_device, \
#     327     f"args mismatch in JIT: {self.captured.expected_st_vars_dtype_device=} != {st_vars_dtype_device=}"
# --> 328   ret = self.captured(input_buffers, var_vals)
#     330 self.cnt += 1
#     331 return ret
#
# File ~/Documents/Coding/gce/nnue/train/.venv/lib/python3.12/site-packages/tinygrad/engine/jit.py:206, in CapturedJit.__call__(self, input_buffers, var_vals)
#     203   self._first_run = False
#     205 if DEBUG >= 1 and len(self._jit_cache) >= 10: print(f"jit execs {len(self._jit_cache)} kernels")
# --> 206 for ei in self._jit_cache: ei.run(var_vals, jit=True)
#     207 self._clear_inputs()
#     208 return self.ret
#
# File ~/Documents/Coding/gce/nnue/train/.venv/lib/python3.12/site-packages/tinygrad/engine/realize.py:127, in ExecItem.run(self, _var_vals, wait, jit, do_update_stats)
#     125 var_vals = self.fixedvars if _var_vals is None else (_var_vals|self.fixedvars)
#     126 bufs = [cast(Buffer, x) for x in self.bufs] if jit else [cast(Buffer, x).ensure_allocated() for x in self.bufs]
# --> 127 et = self.prg(bufs, var_vals, wait=wait or DEBUG >= 2)
#     128 if do_update_stats:
#     129   GlobalCounters.kernel_count += 1
#
# File ~/Documents/Coding/gce/nnue/train/.venv/lib/python3.12/site-packages/tinygrad/engine/realize.py:92, in BufferCopy.__call__(self, rawbufs, var_vals, wait)
#      90 assert dest.size == src.size and dest.dtype == src.dtype, f"buffer copy mismatch, {dest.size} != {src.size}, {dest.dtype} != {src.dtype}"
#      91 st = time.perf_counter()
# ---> 92 self.copy(dest, src)
#      93 if wait:
#      94   Device[dest.device].synchronize()
#
# File ~/Documents/Coding/gce/nnue/train/.venv/lib/python3.12/site-packages/tinygrad/engine/realize.py:87, in BufferCopy.copy(self, dest, src)
#      85   src.allocator._copyout(dest.allocator._as_buffer(dest._buf), src._buf)
#      86 else:
# ---> 87   dest.copyin(src.as_buffer(allow_zero_copy=True))
#
# File ~/Documents/Coding/gce/nnue/train/.venv/lib/python3.12/site-packages/tinygrad/device.py:161, in Buffer.as_buffer(self, allow_zero_copy, force_zero_copy)
#     159   return self.allocator._as_buffer(self._buf)
#     160 assert not force_zero_copy, "force zero copy was passed, but copy is required"
# --> 161 return self.copyout(memoryview(bytearray(self.nbytes)))
#
# KeyboardInterrupt:
